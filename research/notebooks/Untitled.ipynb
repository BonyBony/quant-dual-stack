# %%
from pipelines.cpo.train_macd_cpo import main
main("configs/cpo/macd_cpo.yaml")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pipelines.cpo.train_macd_cpo import main
#       2 main("configs/cpo/macd_cpo.yaml")
#
# ModuleNotFoundError: No module named 'pipelines'
