# %%
import yfinance as yf
print(yf.download("ZOMATO.NS", start="2023-01-01", end="2023-12-31"))
# Out:
# /tmp/ipykernel_5270/3510142698.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   print(yf.download("ZOMATO.NS", start="2023-01-01", end="2023-12-31"))
# HTTP Error 404:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZOMATO.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Empty DataFrame
# Columns: [(Adj Close, ZOMATO.NS), (Close, ZOMATO.NS), (High, ZOMATO.NS), (Low, ZOMATO.NS), (Open, ZOMATO.NS), (Volume, ZOMATO.NS)]
# Index: []

# %%
from research.strategies.macd import MACDStrategy, MACDParams
from common.data.yf_loader import load_daily

df = load_daily("HDFCBANK.NS", "2023-01-01", "2023-01-31")
params = MACDParams(fast=6, slow=20, signal=5)
strat = MACDStrategy()
print(strat.run_day(df, params))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from research.strategies.macd import MACDStrategy, MACDParams
#       2 from common.data.yf_loader import load_daily
#       4 df = load_daily("HDFCBANK.NS", "2023-01-01", "2023-01-31")
#
# ModuleNotFoundError: No module named 'research'
